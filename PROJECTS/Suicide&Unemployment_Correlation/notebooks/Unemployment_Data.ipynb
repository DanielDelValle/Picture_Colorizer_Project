# %%
import pandas as pd
import numpy as np
from counlist import countrylist

# %%
unemployment = pd.read_csv("..\\documentation\\unemployment_all_ratio.csv")
print(unemployment.dtypes, "\n\n", "Rows, Columns: ", unemployment.shape,"\n\n", unemployment.columns, "\n\n", unemployment.head())
# Out:
# COUNTRY                   object
# Country                   object
# SEX                       object
# Sex                       object
# AGE                        int64
# Age                       object
# SERIES                    object
# Series                    object
# FREQ                      object
# Frequency                 object
# TIME                       int64
# Time                       int64
# Unit Code                 object
# Unit                      object
# PowerCode Code             int64
# PowerCode                 object
# Reference Period Code    float64
# Reference Period         float64
# Value                    float64
# Flag Codes               float64
# Flags                    float64
# dtype: object
#
#  Rows, Columns:  (199887, 21)
#
#  Index(['COUNTRY', 'Country', 'SEX', 'Sex', 'AGE', 'Age', 'SERIES', 'Series',
#        'FREQ', 'Frequency', 'TIME', 'Time', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')
#
#    COUNTRY    Country SEX          Sex   AGE       Age SERIES  \
# 0     AUS  Australia  MW  All persons  1519  15 to 19    EPR
# 1     AUS  Australia  MW  All persons  1519  15 to 19    EPR
# 2     AUS  Australia  MW  All persons  1519  15 to 19    EPR
# 3     AUS  Australia  MW  All persons  1519  15 to 19    EPR
# 4     AUS  Australia  MW  All persons  1519  15 to 19    EPR
#
#                         Series FREQ Frequency  ...  Time  Unit Code  \
# 0  Employment/population ratio    A    Annual  ...  2000         PC
# 1  Employment/population ratio    A    Annual  ...  2001         PC
# 2  Employment/population ratio    A    Annual  ...  2002         PC
# 3  Employment/population ratio    A    Annual  ...  2003         PC
# 4  Employment/population ratio    A    Annual  ...  2004         PC
#
#          Unit PowerCode Code  PowerCode Reference Period Code  \
# 0  Percentage              0      Units                   NaN
# 1  Percentage              0      Units                   NaN
# 2  Percentage              0      Units                   NaN
# 3  Percentage              0      Units                   NaN
# 4  Percentage              0      Units                   NaN
#
#    Reference Period      Value  Flag Codes  Flags
# 0               NaN  49.215684         NaN    NaN
# 1               NaN  49.416769         NaN    NaN
# 2               NaN  49.012172         NaN    NaN
# 3               NaN  49.897541         NaN    NaN
# 4               NaN  50.394122         NaN    NaN
#
# [5 rows x 21 columns]

# %%
unemployment = unemployment.loc[unemployment['Series'] == "Unemployment rate"]  #selecting only values of interest

# %%
unemployment.head()
# Out:
#     COUNTRY    Country SEX          Sex   AGE       Age SERIES  \
# 120     AUS  Australia  MW  All persons  1519  15 to 19     UR
# 121     AUS  Australia  MW  All persons  1519  15 to 19     UR
# 122     AUS  Australia  MW  All persons  1519  15 to 19     UR
# 123     AUS  Australia  MW  All persons  1519  15 to 19     UR
# 124     AUS  Australia  MW  All persons  1519  15 to 19     UR
#
#                 Series FREQ Frequency  ...  Time  Unit Code        Unit  \
# 120  Unemployment rate    A    Annual  ...  2000         PC  Percentage
# 121  Unemployment rate    A    Annual  ...  2001         PC  Percentage
# 122  Unemployment rate    A    Annual  ...  2002         PC  Percentage
# 123  Unemployment rate    A    Annual  ...  2003         PC  Percentage
# 124  Unemployment rate    A    Annual  ...  2004         PC  Percentage
#
#     PowerCode Code  PowerCode Reference Period Code  Reference Period  \
# 120              0      Units                   NaN               NaN
# 121              0      Units                   NaN               NaN
# 122              0      Units                   NaN               NaN
# 123              0      Units                   NaN               NaN
# 124              0      Units                   NaN               NaN
#
#          Value  Flag Codes  Flags
# 120  16.210327         NaN    NaN
# 121  17.677139         NaN    NaN
# 122  16.854612         NaN    NaN
# 123  15.695871         NaN    NaN
# 124  15.622854         NaN    NaN
#
# [5 rows x 21 columns]

# %%
unemp = unemployment.loc[unemployment["Country"].isin(countrylist)]      #selecting values only for countries in both dataframes

# %%
unemp = unemp[~unemp.Country.str.contains("Euro")]                #discarding groups of countries(no info in the other dataframe)
unemp = unemp[~unemp.Country.str.contains("OECD")]

# %%
unemp.shape
# Out:
# (58402, 21)

# %%
unemp = unemployment.rename(columns={'SEX': 'Gender', 'Value':'Unemploy_Rate', "Time": "Year"})   #renaming columns for better understanding and according to the other dataframe

# %%
unemp = unemp[['Country', 'Gender', 'Age', 'Year', 'Unemploy_Rate']]     #selecting only needed columns

# %%
unemp.year.unique() #check years range
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-2a6b83a5a368> in <module>
# ----> 1 unemp.year.unique() #check years range
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'year'

# %%
unemp = unemp[unemp['year'] <= 2016]            #setting years range according to suicide dataframe

# %%
unemp.describe()
# Out:
#                  AGE          TIME          Time  PowerCode Code  \
# count   58402.000000  58402.000000  58402.000000         58402.0
# mean    43329.422999   2009.592565   2009.592565             0.0
# std    183396.168967      5.739089      5.739089             0.0
# min      1519.000000   2000.000000   2000.000000             0.0
# 25%      2534.000000   2005.000000   2005.000000             0.0
# 50%      4044.000000   2010.000000   2010.000000             0.0
# 75%      6064.000000   2015.000000   2015.000000             0.0
# max    900000.000000   2019.000000   2019.000000             0.0
#
#        Reference Period Code  Reference Period         Value  Flag Codes  \
# count                    0.0               0.0  58402.000000         0.0
# mean                     NaN               NaN      7.724790         NaN
# std                      NaN               NaN      8.002514         NaN
# min                      NaN               NaN      0.000000         NaN
# 25%                      NaN               NaN      3.249072         NaN
# 50%                      NaN               NaN      5.529585         NaN
# 75%                      NaN               NaN      9.305861         NaN
# max                      NaN               NaN     80.754960         NaN
#
#        Flags
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
unemp.gender.unique()          #check how genders are described
# Out:
# array(['MW', 'MEN', 'WOMEN'], dtype=object)

# %%
unemp.drop(unemp[unemp.gender == 'MW'].index, inplace=True)       #adapt gender descriptions to the dataframe to be contrasted with
unemp.loc[unemp['gender'] == "MEN", 'gender'] = "male"
unemp.loc[unemp['gender'] == "WOMEN", 'gender'] = "female"

# %%
unemp.age.unique() #check how ages are grouped
# Out:
# array(['15 to 19', '15 to 24', '15 to 64', '20 to 24', '25 to 29',
#        '25 to 34', '25 to 39', '25 to 54', '25 to 64', '30 to 34',
#        '35 to 39', '35 to 44', '40 to 44', '40 to 49', '45 to 49',
#        '45 to 54', '50 to 54', '55 to 59', '55 to 64', '60 to 64',
#        '65 to 69', '65+', '70 to 74', '70+', '75+', 'Total', '75 to 79+',
#        '80+'], dtype=object)

# %%
unemp = unemp[(unemp['age'] == '15 to 24') | (unemp['age'] == '25 to 34') |(unemp['age'] == '35 to 44') |(unemp['age'] == '45 to 54') | (unemp['age'] == '55 to 64') |(unemp['age'] == '65 to 69') | (unemp['age'] == '70 to 74')]      #reducing age ranges to common with the dataframe

# %%
unemp['age'] = unemp['age'].str.replace(' to ', '-')  #normalising age format

# %%
#unemp.set_index('country', inplace=True)

# %%
import matplotlib as plt
import seaborn as sns
import plotly as po

# %%
unemp.dtypes
# Out:
# country           object
# gender            object
# age               object
# year               int64
# unemploy_rate    float64
# dtype: object

# %%
sns.distplot(unemp.unemploy_rate, bins=50)
# Out:
# <AxesSubplot:xlabel='unemploy_rate', ylabel='Density'>

# %%
q = sns.FacetGrid(unemp, col="age", hue="gender")
q.map(sns.scatterplot, "year", "unemploy_rate", alpha=.5)
q.add_legend()

# %%
multi_index = pd.pivot_table(unemp, index = ['country', 'age'], values = 'unemploy_rate', aggfunc = 'mean')
